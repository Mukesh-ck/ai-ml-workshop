# %%
import numpy as np
import pandas as pd

data = {
    'student_name': ['Alice', 'Bob', 'Charlie', 'Diana', 'Eve'],
    'hours_studied': [5,8,3,10,6],
    'previous_score': [65, 85, 55, 92, 75],
    'attendance': ['Yes', 'No', 'Yes', 'NO', 'Yes'],
    'sleep_hours': [7, 5, 4, 7, 6],
    'extracurricular': ['Yes', 'No', 'Yes', 'NO', 'Yes'],
    'parent_education': ['Bachelor', 'Master', 'High School', 'PhD', 'Bachelor']
}

df = pd.DataFrame(data)
print("Student Performance DataFrame:")
print(df)

#Basic DataFrame Information 
print("\nDataFrame Shape:", df.shape[0], "rows,", df.shape[1], "columns")
print("Column names:", df.columns.tolist())
print("Data types:\n", df.dtypes)
# Out:
# Student Performance DataFrame:
#   student_name  hours_studied  previous_score attendance  sleep_hours  \
# 0        Alice              5              65        Yes            7
# 1          Bob              8              85         No            5
# 2      Charlie              3              55        Yes            4
# 3        Diana             10              92         NO            7
# 4          Eve              6              75        Yes            6
#
#   extracurricular parent_education
# 0             Yes         Bachelor
# 1              No           Master
# 2             Yes      High School
# 3              NO              PhD
# 4             Yes         Bachelor
#
# DataFrame Shape: 5 rows, 7 columns
# Column names: ['student_name', 'hours_studied', 'previous_score', 'attendance', 'sleep_hours', 'extracurricular', 'parent_education']
# Data types:
#  student_name          str
# hours_studied       int64
# previous_score      int64
# attendance            str
# sleep_hours         int64
# extracurricular       str
# parent_education      str
# dtype: object

# %%
# view data
print("First 5 rows:")
print(df.head())

# view last 2 rows 
print("last 3 rows:")
print(df.tail(2))

# Statistical summary
print("\nStatistical Summary:")
print(df.describe())

# Check for missing values
print("\nMissing values:")
print(df.isnull().sum())

# Check for nan
print("\nCheck nan values")
print(df.isna().sum())
# Out:
# First 5 rows:
#   student_name  hours_studied  previous_score attendance  sleep_hours  \
# 0        Alice              5              65        Yes            7
# 1          Bob              8              85         No            5
# 2      Charlie              3              55        Yes            4
# 3        Diana             10              92         NO            7
# 4          Eve              6              75        Yes            6
#
#   extracurricular parent_education
# 0             Yes         Bachelor
# 1              No           Master
# 2             Yes      High School
# 3              NO              PhD
# 4             Yes         Bachelor
# last 3 rows:
#   student_name  hours_studied  previous_score attendance  sleep_hours  \
# 3        Diana             10              92         NO            7
# 4          Eve              6              75        Yes            6
#
#   extracurricular parent_education
# 3              NO              PhD
# 4             Yes         Bachelor
#
# Statistical Summary:
#        hours_studied  previous_score  sleep_hours
# count       5.000000        5.000000      5.00000
# mean        6.400000       74.400000      5.80000
# std         2.701851       14.892951      1.30384
# min         3.000000       55.000000      4.00000
# 25%         5.000000       65.000000      5.00000
# 50%         6.000000       75.000000      6.00000
# 75%         8.000000       85.000000      7.00000
# max        10.000000       92.000000      7.00000
#
# Missing values:
# student_name        0
# hours_studied       0
# previous_score      0
# attendance          0
# sleep_hours         0
# extracurricular     0
# parent_education    0
# dtype: int64
#
# Check nan values
# student_name        0
# hours_studied       0
# previous_score      0
# attendance          0
# sleep_hours         0
# extracurricular     0
# parent_education    0
# dtype: int64
